# %% [markdown]
# # Scatter

# %%
import hvplot.polars  # noqa
import polars as pl
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="cdb56953-4a93-4997-a5eb-59fd411290fa" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ```scatter``` plots are a good first way to plot data with non continuous axes.

# %%
from bokeh.sampledata.iris import flowers

df = pl.from_pandas(flowers)
df.sample(n=5)
# Out:
# shape: (5, 5)
# ┌──────────────┬─────────────┬──────────────┬─────────────┬────────────┐
# │ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width ┆ species    │
# │ ---          ┆ ---         ┆ ---          ┆ ---         ┆ ---        │
# │ f64          ┆ f64         ┆ f64          ┆ f64         ┆ str        │
# ╞══════════════╪═════════════╪══════════════╪═════════════╪════════════╡
# │ 6.0          ┆ 2.9         ┆ 4.5          ┆ 1.5         ┆ versicolor │
# │ 5.0          ┆ 3.5         ┆ 1.6          ┆ 0.6         ┆ setosa     │
# │ 5.2          ┆ 4.1         ┆ 1.5          ┆ 0.1         ┆ setosa     │
# │ 4.6          ┆ 3.2         ┆ 1.4          ┆ 0.2         ┆ setosa     │
# │ 5.1          ┆ 3.3         ┆ 1.7          ┆ 0.5         ┆ setosa     │
# └──────────────┴─────────────┴──────────────┴─────────────┴────────────┘

# %%
df.hvplot.scatter(x='sepal_length', y='sepal_width', by='species', 
                  legend='top', height=400, width=400)
# Out:
# :NdOverlay   [species]
#    :Scatter   [sepal_length]   (sepal_width)

# %% [markdown]
# As for most other types of hvPlot plots, you can add fields to the hover display using the ```hover_cols``` argument.
# It can also take “all” as input to show all fields.

# %%
df.hvplot.scatter(x='sepal_length', y='sepal_width', s='petal_length', scale=5, by='species', 
                  legend='top', height=400, width=600,
                  hover_cols=["species", "sepal_length", "sepal_width", "petal_width"])
# Out:
# :NdOverlay   [species]
#    :Scatter   [sepal_length]   (sepal_width,petal_length,species,petal_width)

# %% [markdown]
# You can add the ‘s’ parameter in scatter to specify the marker plot size and add the ‘scale’ parameter to specify what the scaling factor should be.
