# %% [markdown]
# # Step

# %%
import hvplot.polars  # noqa
import polars as pl
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ae81c61f-0b0e-463b-ac22-66b4d67624e4" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ```step``` can be used pretty much anytime line might be used and has many of the same options available.

# %%
from bokeh.sampledata.degrees import data as deg

df = pl.from_pandas(deg)
df.sample(n=5)
# Out:
# shape: (5, 18)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ Year ┆ Agricultur ┆ Architectu ┆ Art and    ┆ … ┆ Physical   ┆ Psycholog ┆ Public    ┆ Social    │
# │ ---  ┆ e          ┆ re         ┆ Performanc ┆   ┆ Sciences   ┆ y         ┆ Administr ┆ Sciences  │
# │ i64  ┆ ---        ┆ ---        ┆ e          ┆   ┆ ---        ┆ ---       ┆ ation     ┆ and       │
# │      ┆ f64        ┆ f64        ┆ ---        ┆   ┆ f64        ┆ f64       ┆ ---       ┆ History   │
# │      ┆            ┆            ┆ f64        ┆   ┆            ┆           ┆ f64       ┆ ---       │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ f64       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1987 ┆ 31.486429  ┆ 38.730675  ┆ 61.7       ┆ … ┆ 30.4       ┆ 70.1      ┆ 76.4      ┆ 43.9      │
# ...

# %%
df.hvplot.step(x='Year', y=['Art and Performance', 'Business', 'Biology', 'Education', 'Computer Science'], 
                value_label='% of Degrees Earned by Women', legend='top', height=500, width=620)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Year]   (% of Degrees Earned by Women)
